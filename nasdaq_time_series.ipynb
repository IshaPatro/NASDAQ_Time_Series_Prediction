# %% [markdown]
# # Environment Setup

# %%
# %%capture
# %pip install -r requirements.txt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Load Your NASDAQ Data

# %%
df = pd.read_csv('data/HistoricalData.csv')
df.rename(columns={ 'Close/Last': 'Close'}, inplace=True)
df['Date'] = pd.to_datetime(df['Date'])
df.sort_values(by='Date', ascending=True, inplace=True)
df.head(5)
# Out:
#            Date    Close     Open     High      Low
# 2516 2015-08-17  5091.70  5032.34  5092.69  5022.42
# 2515 2015-08-18  5059.35  5082.17  5085.14  5054.97
# 2514 2015-08-19  5019.05  5039.03  5060.93  4992.85
# 2513 2015-08-20  4877.49  4973.49  4986.51  4877.49
# 2512 2015-08-21  4706.04  4801.04  4856.75  4706.04

# %% [markdown]
# # Data Validation

# %%
df.isnull().sum()
# Out:
# Date     0
# Close    0
# Open     0
# High     0
# Low      0
# dtype: int64

# %% [markdown]
# Verified the dataset for missing values \
# The result shows **0 null values across all columns**, which means the dataset is complete and does not require any imputation or data cleaning for missing entries.

# %% [markdown]
# # Add Technical Indicators

# %% [markdown]
# To enrich our analysis, we computed several key technical indicators:
#
# - **Daily & Log Returns**: Capture percentage and log-based changes in price, essential for understanding performance and risk.
# - **Moving Averages (5, 10, 20 days)**: Smooth short- and medium-term price trends, helping to identify momentum and potential support/resistance levels.
# - **Volatility (5, 10 days)**: Rolling standard deviation of returns, indicating short-term risk and market uncertainty.
# - **RSI (14 days)**: Measures speed and magnitude of price movements to identify overbought/oversold conditions.
# - **Bollinger Bands (20 days)**: Track price deviations around the moving average, highlighting volatility shifts and potential breakout points.
#
# These indicators provide multiple perspectives (trend, momentum, volatility), adding depth to the raw price data and strengthening both descriptive and predictive analysis.

# %%
# Returns
df['Daily_Return'] = df['Close'].pct_change()
df['Log_Return'] = np.log(df['Close'] / df['Close'].shift(1))
df.head()
# Out:
#            Date    Close     Open     High      Low  Daily_Return  Log_Return
# 2516 2015-08-17  5091.70  5032.34  5092.69  5022.42           NaN         NaN
# 2515 2015-08-18  5059.35  5082.17  5085.14  5054.97     -0.006353   -0.006374
# 2514 2015-08-19  5019.05  5039.03  5060.93  4992.85     -0.007965   -0.007997
# 2513 2015-08-20  4877.49  4973.49  4986.51  4877.49     -0.028205   -0.028610
# 2512 2015-08-21  4706.04  4801.04  4856.75  4706.04     -0.035151   -0.035784

# %%
# Moving averages
df['MA_5'] = df['Close'].rolling(window=5).mean()
df['MA_10'] = df['Close'].rolling(window=10).mean()
df['MA_20'] = df['Close'].rolling(window=20).mean()
df.head()
# Out:
#            Date    Close     Open     High      Low  Daily_Return  Log_Return  \
# 2516 2015-08-17  5091.70  5032.34  5092.69  5022.42           NaN         NaN
# 2515 2015-08-18  5059.35  5082.17  5085.14  5054.97     -0.006353   -0.006374
# 2514 2015-08-19  5019.05  5039.03  5060.93  4992.85     -0.007965   -0.007997
# 2513 2015-08-20  4877.49  4973.49  4986.51  4877.49     -0.028205   -0.028610
# 2512 2015-08-21  4706.04  4801.04  4856.75  4706.04     -0.035151   -0.035784
#
#           MA_5  MA_10  MA_20
# 2516       NaN    NaN    NaN
# 2515       NaN    NaN    NaN
# 2514       NaN    NaN    NaN
# 2513       NaN    NaN    NaN
# 2512  4950.726    NaN    NaN

# %%
# RSI
delta = df['Close'].diff()
gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
rs = gain / loss
df['RSI'] = 100 - (100 / (1 + rs))
df
# Out:
#            Date     Close      Open      High       Low  Daily_Return  \
# 2516 2015-08-17   5091.70   5032.34   5092.69   5022.42           NaN
# 2515 2015-08-18   5059.35   5082.17   5085.14   5054.97     -0.006353
# 2514 2015-08-19   5019.05   5039.03   5060.93   4992.85     -0.007965
# 2513 2015-08-20   4877.49   4973.49   4986.51   4877.49     -0.028205
# 2512 2015-08-21   4706.04   4801.04   4856.75   4706.04     -0.035151
# ...         ...       ...       ...       ...       ...           ...
# 4    2025-08-08  21450.02  21316.37  21464.53  21284.97      0.009760
# 3    2025-08-11  21385.40  21459.65  21549.73  21346.62     -0.003013
# 2    2025-08-12  21681.90  21507.44  21689.68  21386.25      0.013865
# 1    2025-08-13  21713.14  21764.55  21803.75  21645.14      0.001441
# 0    2025-08-14  21710.67  21649.21  21766.29  21627.13     -0.000114
#
#       Log_Return       MA_5      MA_10       MA_20        RSI
# 2516         NaN        NaN        NaN         NaN        NaN
# 2515   -0.006374        NaN        NaN         NaN        NaN
# 2514   -0.007997        NaN        NaN         NaN        NaN
# 2513   -0.028610        NaN        NaN         NaN        NaN
# 2512   -0.035784   4950.726        NaN         NaN        NaN
# ...          ...        ...        ...         ...        ...
# 4       0.009712  21166.454  21101.139  20994.7235  61.705739
# 3      -0.003017  21232.818  21121.821  21031.9770  62.222178
# 2       0.013769  21385.888  21180.182  21082.1820  65.147105
# 1       0.001440  21494.632  21238.529  21131.3145  65.039896
# 0      -0.000114  21588.226  21297.351  21172.5655  64.138012
#
# [2517 rows x 11 columns]

# %%
# Bollinger Bands
df['BB_Middle'] = df['Close'].rolling(window=20).mean()
bb_std = df['Close'].rolling(window=20).std()
df['BB_Upper'] = df['BB_Middle'] + (bb_std * 2)
df['BB_Lower'] = df['BB_Middle'] - (bb_std * 2)
df
# Out:
#            Date     Close      Open      High       Low  Daily_Return  \
# 2516 2015-08-17   5091.70   5032.34   5092.69   5022.42           NaN
# 2515 2015-08-18   5059.35   5082.17   5085.14   5054.97     -0.006353
# 2514 2015-08-19   5019.05   5039.03   5060.93   4992.85     -0.007965
# 2513 2015-08-20   4877.49   4973.49   4986.51   4877.49     -0.028205
# 2512 2015-08-21   4706.04   4801.04   4856.75   4706.04     -0.035151
# ...         ...       ...       ...       ...       ...           ...
# 4    2025-08-08  21450.02  21316.37  21464.53  21284.97      0.009760
# 3    2025-08-11  21385.40  21459.65  21549.73  21346.62     -0.003013
# 2    2025-08-12  21681.90  21507.44  21689.68  21386.25      0.013865
# 1    2025-08-13  21713.14  21764.55  21803.75  21645.14      0.001441
# 0    2025-08-14  21710.67  21649.21  21766.29  21627.13     -0.000114
#
#       Log_Return       MA_5      MA_10       MA_20        RSI   BB_Middle  \
# 2516         NaN        NaN        NaN         NaN        NaN         NaN
# 2515   -0.006374        NaN        NaN         NaN        NaN         NaN
# 2514   -0.007997        NaN        NaN         NaN        NaN         NaN
# 2513   -0.028610        NaN        NaN         NaN        NaN         NaN
# 2512   -0.035784   4950.726        NaN         NaN        NaN         NaN
# ...          ...        ...        ...         ...        ...         ...
# 4       0.009712  21166.454  21101.139  20994.7235  61.705739  20994.7235
# 3      -0.003017  21232.818  21121.821  21031.9770  62.222178  21031.9770
# 2       0.013769  21385.888  21180.182  21082.1820  65.147105  21082.1820
# 1       0.001440  21494.632  21238.529  21131.3145  65.039896  21131.3145
# 0      -0.000114  21588.226  21297.351  21172.5655  64.138012  21172.5655
#
#           BB_Upper      BB_Lower
# 2516           NaN           NaN
# 2515           NaN           NaN
# 2514           NaN           NaN
# 2513           NaN           NaN
# 2512           NaN           NaN
# ...            ...           ...
# 4     21418.397478  20571.049522
# 3     21455.471286  20608.482714
# 2     21563.068882  20601.295118
# 1     21659.387182  20603.241818
# 0     21746.720705  20598.410295
#
# [2517 rows x 14 columns]

# %%
df.isnull().sum()
# Out:
# Date             0
# Close            0
# Open             0
# High             0
# Low              0
# Daily_Return     1
# Log_Return       1
# MA_5             4
# MA_10            9
# MA_20           19
# RSI             13
# BB_Middle       19
# BB_Upper        19
# BB_Lower        19
# dtype: int64

# %% [markdown]
# # Null Value Handling
#
# After adding technical indicators, we now have null values due to rolling calculations. We need to handle these appropriately for our analysis.

# %%
print("Null values in each column:")
print(df.isnull().sum())
print(f"\nTotal rows: {len(df)}")
print(f"Rows with any null values: {df.isnull().any(axis=1).sum()}")

print("\nFirst 25 rows showing null pattern:")
print(df.head(25)[['Date', 'Close', 'Daily_Return', 'MA_5', 'MA_10', 'MA_20', 'RSI']].to_string())
# Out:
# Null values in each column:
# Date             0
# Close            0
# Open             0
# High             0
# Low              0
# Daily_Return     1
# Log_Return       1
# MA_5             4
# MA_10            9
# MA_20           19
# RSI             13
# BB_Middle       19
# BB_Upper        19
# BB_Lower        19
# dtype: int64
#
# Total rows: 2517
# Rows with any null values: 19
#
# First 25 rows showing null pattern:
#            Date    Close  Daily_Return      MA_5     MA_10      MA_20        RSI
# 2516 2015-08-17  5091.70           NaN       NaN       NaN        NaN        NaN
# 2515 2015-08-18  5059.35     -0.006353       NaN       NaN        NaN        NaN
# 2514 2015-08-19  5019.05     -0.007965       NaN       NaN        NaN        NaN
# 2513 2015-08-20  4877.49     -0.028205       NaN       NaN        NaN        NaN
# 2512 2015-08-21  4706.04     -0.035151  4950.726       NaN        NaN        NaN
# 2511 2015-08-24  4526.25     -0.038204  4837.636       NaN        NaN        NaN
# 2510 2015-08-25  4506.49     -0.004366  4727.064       NaN        NaN        NaN
# 2509 2015-08-26  4697.54      0.042394  4662.762       NaN        NaN        NaN
# 2508 2015-08-27  4812.71      0.024517  4649.806       NaN        NaN        NaN
# 2507 2015-08-28  4828.32      0.003243  4674.262  4812.494        NaN        NaN
# 2506 2015-08-31  4776.51     -0.010730  4724.314  4780.975        NaN        NaN
# 2505 2015-09-01  4636.10     -0.029396  4750.236  4738.650        NaN        NaN
# 2504 2015-09-02  4749.98      0.024564  4760.724  4711.743        NaN        NaN
# 2503 2015-09-03  4733.50     -0.003469  4744.882  4697.344        NaN  35.434524
# 2502 2015-09-04  4683.92     -0.010474  4716.002  4695.132        NaN  34.061132
# 2501 2015-09-07  4683.92      0.000000  4697.484  4710.899        NaN  34.944861
# 2500 2015-09-08  4811.93      0.027330  4732.650  4741.443        NaN  42.240139
# 2499 2015-09-09  4756.53     -0.011513  4733.960  4747.342        NaN  45.155399
# 2498 2015-09-10  4796.25      0.008351  4746.510  4745.696        NaN  54.039242
# 2497 2015-09-11  4822.34      0.005440  4774.194  4745.098  4778.7960  65.373791
# 2496 2015-09-14  4805.76     -0.003438  4798.562  4748.023  4764.4990  65.590390
# 2495 2015-09-15  4860.52      0.011395  4808.280  4770.465  4754.5575  59.895568
# 2494 2015-09-16  4889.24      0.005909  4834.822  4784.391  4748.0670  55.191642
# 2493 2015-09-17  4893.95      0.000963  4854.362  4800.436  4748.8900  54.519039
# 2492 2015-09-18  4827.23     -0.013633  4855.340  4814.767  4754.9495  53.422125

# %%
# Strategic null handling for specific columns
# Handle different types of nulls with domain-specific logic
df_strategic = df.copy()

# For returns, fill first value with 0 (no return on first day)
df_strategic['Daily_Return'].fillna(0, inplace=True)
df_strategic['Log_Return'].fillna(0, inplace=True)

# For moving averages, use the closing price for initial values
df_strategic['MA_5'].fillna(df_strategic['Close'], inplace=True)
df_strategic['MA_10'].fillna(df_strategic['Close'], inplace=True)
df_strategic['MA_20'].fillna(df_strategic['Close'], inplace=True)
df_strategic['BB_Middle'].fillna(df_strategic['Close'], inplace=True)
df_strategic['BB_Upper'].fillna(df_strategic['Close'], inplace=True)
df_strategic['BB_Lower'].fillna(df_strategic['Close'], inplace=True)

# For RSI, use neutral value of 50 (neither overbought nor oversold)
df_strategic['RSI'].fillna(50, inplace=True)

print(f"Null values remaining: {df_strategic.isnull().sum().sum()}")
print(f"All rows preserved: {len(df_strategic)} rows")

# Show first few rows
print("\nFirst 10 rows after strategic filling:")
print(df_strategic.head(10)[['Date', 'Close', 'Daily_Return', 'MA_5', 'MA_10', 'MA_20', 'RSI']].to_string())
# Out:
# Null values remaining: 0
# All rows preserved: 2517 rows
#
# First 10 rows after strategic filling:
#            Date    Close  Daily_Return      MA_5     MA_10    MA_20   RSI
# 2516 2015-08-17  5091.70      0.000000  5091.700  5091.700  5091.70  50.0
# 2515 2015-08-18  5059.35     -0.006353  5059.350  5059.350  5059.35  50.0
# 2514 2015-08-19  5019.05     -0.007965  5019.050  5019.050  5019.05  50.0
# 2513 2015-08-20  4877.49     -0.028205  4877.490  4877.490  4877.49  50.0
# 2512 2015-08-21  4706.04     -0.035151  4950.726  4706.040  4706.04  50.0
# 2511 2015-08-24  4526.25     -0.038204  4837.636  4526.250  4526.25  50.0
# 2510 2015-08-25  4506.49     -0.004366  4727.064  4506.490  4506.49  50.0
# 2509 2015-08-26  4697.54      0.042394  4662.762  4697.540  4697.54  50.0
# 2508 2015-08-27  4812.71      0.024517  4649.806  4812.710  4812.71  50.0
# 2507 2015-08-28  4828.32      0.003243  4674.262  4812.494  4828.32  50.0

# %% [markdown]
# # Date Handling and Proper Sorting
#
# Convert the Date column to datetime format and sort chronologically

# %%
# Check current date format and sample
print("Current Date column info:")
print(f"Data type: {df_strategic['Date'].dtype}")
print(f"Sample dates:")
print(df_strategic['Date'].head(10).tolist())
print(f"\nDate range (as strings): {df_strategic['Date'].min()} to {df_strategic['Date'].max()}")

# Convert Date column to datetime
print("\nConverting Date column to datetime format...")


print(f"After conversion:")
print(f"Data type: {df_strategic['Date'].dtype}")
print(f"Date range: {df_strategic['Date'].min()} to {df_strategic['Date'].max()}")
# Out:
# Current Date column info:
# Data type: datetime64[ns]
# Sample dates:
# [Timestamp('2015-08-17 00:00:00'), Timestamp('2015-08-18 00:00:00'), Timestamp('2015-08-19 00:00:00'), Timestamp('2015-08-20 00:00:00'), Timestamp('2015-08-21 00:00:00'), Timestamp('2015-08-24 00:00:00'), Timestamp('2015-08-25 00:00:00'), Timestamp('2015-08-26 00:00:00'), Timestamp('2015-08-27 00:00:00'), Timestamp('2015-08-28 00:00:00')]
#
# Date range (as strings): 2015-08-17 00:00:00 to 2025-08-14 00:00:00
#
# Converting Date column to datetime format...
# After conversion:
# Data type: datetime64[ns]
# Date range: 2015-08-17 00:00:00 to 2025-08-14 00:00:00

# %% [markdown]
# # Save Processed Data

# %%
df.to_csv('data/processed/nasdaq_processed.csv')
print(f"Final dataset shape: {df.shape}")
print(f"Date range: {df['Date'].min()} to {df['Date'].max()}")
# Out:
# Final dataset shape: (2517, 14)
# Date range: 2015-08-17 00:00:00 to 2025-08-14 00:00:00

# %%
df.describe()
# Out:
#                                 Date         Close          Open  \
# count                           2517   2517.000000   2517.000000
# mean   2020-08-10 20:12:52.348033536  10718.455737  10710.819710
# min              2015-08-17 00:00:00   4266.840000      0.000000
# 25%              2018-02-09 00:00:00   6963.850000   6959.630000
# 50%              2020-08-11 00:00:00  10536.270000  10531.640000
# 75%              2023-02-09 00:00:00  14047.500000  14045.210000
# max              2025-08-14 00:00:00  21713.140000  21764.550000
# std                              NaN   4484.646077   4495.744077
#
#                High           Low  Daily_Return   Log_Return          MA_5  \
# count   2517.000000   2517.000000   2517.000000  2517.000000   2517.000000
# mean   10784.306544  10630.028713      0.000674     0.000576  10705.189643
# min        0.000000      0.000000     -0.123213    -0.131492   4288.090000
# 25%     7025.850000   6903.390000     -0.005132    -0.005145   6973.064000
# 50%    10608.840000  10399.860000      0.001062     0.001062  10537.388000
# 75%    14141.070000  13952.800000      0.007681     0.007651  14024.144000
# max    21803.750000  21645.140000      0.121632     0.114784  21588.226000
# std     4526.662353   4459.469325      0.013985     0.014011   4474.711953
#
#               MA_10         MA_20          RSI     BB_Middle      BB_Upper  \
# count   2517.000000   2517.000000  2517.000000   2517.000000   2517.000000
# mean   10688.463789  10655.962749    56.689441  10655.962749  11113.100106
# min     4376.558000   4453.875500    11.622703   4453.875500   4506.490000
# 25%     6998.523000   6958.882500    44.577824   6958.882500   7303.435574
# 50%    10563.937000  10613.072000    57.865898  10613.072000  11115.914538
# 75%    13972.374000  13912.542500    69.076209  13912.542500  14522.027622
# max    21297.351000  21172.565500    99.333906  21172.565500  21746.720705
# std     4464.156073   4443.516938    16.308729   4443.516938   4658.134250
#
#            BB_Lower
# count   2517.000000
# mean   10198.825392
# min     4190.676984
# 25%     6689.660118
# 50%    10088.318308
# 75%    13291.345724
# max    20608.482714
# std     4243.239095
